# %%
import numpy as np
import pandas as pd
import re

# %%
PRICES_STOCK_CSV = "PRICES-STOCK.csv"
PRODUCTS_CSV = "PRODUCTS.csv"

def process_csv_files():
    # Read csv files into separate dataframes
    prices_stock_df = pd.read_csv(PRICES_STOCK_CSV, sep='|'  , engine='python')
    products_df = pd.read_csv(PRODUCTS_CSV, sep='|'  , engine='python')
    
    # Join the prices/stock dataframe and products dataframe
    df_merge = pd.merge(products_df, prices_stock_df, how='right')
    return df_merge

def data_cleaning(dataframe):
    # Clean text
    new_products = dataframe['ITEM_DESCRIPTION'].str.replace("[<p>/]","", regex=True)
    dataframe['ITEM_DESCRIPTION'] = new_products

    # Combine category, sub-category, and sub-sub-category into one category 
    # separated by a pipe symbol in lower case
    dataframe['Category'] = dataframe['CATEGORY'] + ' | ' + dataframe['SUB_CATEGORY'] + ' | ' + dataframe['SUB_SUB_CATEGORY']
    
    # Extract package from item description
    pattern = re.compile(r'(\d+(?!.*\d).*)')
    s = dataframe['ITEM_DESCRIPTION'].str.extract(pattern, expand=True)
    dataframe['Package'] = s
    
    # Format data
    dataframe['Category'] = dataframe['Category'].str.title()
    dataframe['ITEM_NAME'] = dataframe['ITEM_NAME'].str.title()
    dataframe['ITEM_DESCRIPTION'] = dataframe['ITEM_DESCRIPTION'].str.title()
    dataframe['BRAND_NAME'] = dataframe['BRAND_NAME'].str.title()
    
    return dataframe


def select_branch(dataframe, branch1, branch2):
    # Select only MM and RHSM branches that have stock
    filt = ((dataframe['BRANCH'] == branch1) | (dataframe['BRANCH'] == branch2)) & (dataframe['STOCK'] > 0)
    filt_branch_stock = dataframe.loc[filt]
    
    # Create new dataframe with necessary columns for api
    final_df = filt_branch_stock[['EAN', 'BRANCH', 'PRICE', 'STOCK', 'BRAND_NAME', 'Category', 'ITEM_DESCRIPTION', 'ITEM_IMG', 'ITEM_NAME', 'Package', 'SKU']]
    
    return final_df

if __name__ == "__main__":
    merge_df = process_csv_files()
    clean_data = data_cleaning(merge_df)
    results = select_branch(clean_data, 'MM', 'RHSM')
    results.head()

# %%
results
# Out:
#                    EAN BRANCH  PRICE  STOCK     BRAND_NAME  \
# 1        7501035912854   RHSM   15.3      5    Studio Line
# 15       8410030007788   RHSM   64.2      5       Microlab
# 18         33383653006   RHSM   79.5      3        Karcher
# 22         40000658928     MM   23.7      5  Altec Lansing
# 25        780292000652   RHSM   47.1      2            H2O
# ...                ...    ...    ...    ...            ...
# 2296732  5013665113355   RHSM   36.0      3      Sterilite
# 2296742  3700906700338     MM   81.9      2         Canada
# 2296752  7506145820570     MM   49.2      1     Damablanca
# 2296764  7503023492065   RHSM   59.4      3     Baby Shark
# 2296766  7501010776754     MM    4.5      5   Westinghouse
#
#                                                   Category  \
# 1        Deli Meat & Cheese | Service Deli | Com Prepar...
# 15       Hardlines | Disposable And Birthday Party Supp...
# 18                      Bakery | Bakery | Cakes - In Store
# 22        Hardlines | Stationary & Party Goods | Cuadernos
# 25                    Home | Domestic Goods | Toallas Baño
# ...                                                    ...
# 2296732               Hardlines | Books And Gifts | Todo A
# 2296742       Consumables | Health And Beauty Aids | Color
# 2296752  Pets | Pets And Supplies | Mascotas - Cuidado ...
# 2296764  Grocery | 92 Grocery | Dessert-Topping Filling...
# 2296766  Hardlines | Stationary & Party Goods | Crafts ...
#
#                                          ITEM_DESCRIPTION  \
# 1                    Cepillo Dental Infantil Tarzan 0 Pza
# 15                Vino Tinto Maruqes De Penamonte 750 Ml.
# 18                                  Corazon De Apio 1 Pza
# 22                               Calcetin Dep Bgn3739 1Un
# 25                              Q Crema Unt Nat 100 100Gr
# ...                                                   ...
# 2296732  Crema 100% De Cacahuates Organica Crujie 227 Grs
# 2296742                Vino Rosado Divine Justine 750 Ml.
# 2296752          Cobertor Home Line Cmfe1802Sb Matrimonia
# 2296764                Sandalia Simple Fash, 23, Plateado
# 2296766                              Tenedor Jumbo 25 Bol
#
#                                                   ITEM_IMG  \
# 1        https://locahost:8000/images/7501035912854?hei...
# 15       https://locahost:8000/images/8410030007788?hei...
# 18       https://locahost:8000/images/33383653006?heigh...
# 22       https://locahost:8000/images/40000658928?heigh...
# 25       https://locahost:8000/images/780292000652?heig...
# ...                                                    ...
# 2296732  https://locahost:8000/images/5013665113355?hei...
# 2296742  https://locahost:8000/images/3700906700338?hei...
# 2296752  https://locahost:8000/images/7506145820570?hei...
# 2296764  https://locahost:8000/images/7503023492065?hei...
# 2296766  https://locahost:8000/images/7501010776754?hei...
#
#                                         ITEM_NAME            Package     SKU
# 1                  Cepillo Dental Infantil Tarzan              0 PZA  223240
# 15                Vino Tinto Maruqes De Penamonte            750 ML.   85778
# 18                                Corazon De Apio              1 PZA  111612
# 22                             Calcetin Deportivo                1UN   58179
# 25                                Untable/Fundido              100GR   23522
# ...                                           ...                ...     ...
# 2296732  Crema 100% De Cacahuates Organica Crujie            227 GRS  133086
# 2296742                Vino Rosado Divine Justine            750 ML.   87273
# 2296752  Cobertor Home Line Cmfe1802Sb Matrimonia  1802SB MATRIMONIA  306369
# 2296764        Sandalia Simple Fash, 23, Plateado       23, PLATEADO  296517
# 2296766                             Tenedor Jumbo             25 BOL  196940
#
# [460002 rows x 11 columns]

# %%
import json

top_mm_products = results.sort_values(['PRICE', 'BRANCH'], ascending=[0,1]).head(10)

result = top_mm_products.to_json(orient="records")

parsed = json.loads(result)

json.dumps(parsed)
# Out:
# '[{"EAN": 72649244, "BRANCH": "MM", "PRICE": 90.3, "STOCK": 4, "BRAND_NAME": "Lubritek", "Category": "Hardlines | Sporting Goods | Piscina & Juegos Agua", "ITEM_DESCRIPTION": "Toallita Humeda C30 Pzas 1 Pza", "ITEM_IMG": "https://locahost:8000/images/72649244?height=500&width=500", "ITEM_NAME": "Toallita Humeda C/30 Pzas", "Package": "1 PZA", "SKU": 251261}, {"EAN": 7501325703346, "BRANCH": "MM", "PRICE": 90.3, "STOCK": 5, "BRAND_NAME": "San Blas", "Category": "Grocery | 92 Grocery | Crackers - Salty-Savory", "ITEM_DESCRIPTION": "Salchicha Alpino Para Asar 800 Gr", "ITEM_IMG": "https://locahost:8000/images/7501325703346?height=500&width=500", "ITEM_NAME": "Salchicha Alpino Para Asar 800 Gr", "Package": "800 GR", "SKU": 285805}, {"EAN": 789115006087, "BRANCH": "MM", "PRICE": 90.3, "STOCK": 3, "BRAND_NAME": "Pax", "Category": "Impulse Merchandise | Checkouts/Batteries | Checkouts - Colas Pegamentos & Sellantes", "ITEM_DESCRIPTION": "Acond Super 40 170Ml 170Ml", "ITEM_IMG": "https://locahost:8000/images/789115006087?height=500&width=500", "ITEM_NAME": "Acond Tod/Tipo Cab", "Package": "170ML", "SKU": 38057}, {"EAN": 7506078947443, "BRANCH": "MM", "PRICE": 90.3, "STOCK": 5, "BRAND_NAME": "Rana", "Category": "Apparel | Girls Wear | Outwear", "ITEM_DESCRIPTION": "Oa Tinte Imediamini Leche Gratis 467 Grs", "ITEM_IMG": "https://locahost:8000/images/7506078947443?height=500&width=500", "ITEM_NAME": "Oa Tinte Imediamini Leche Gratis", "Package": "467 GRS", "SKU": 206648}, {"EAN": 7501010788818, "BRANCH": "MM", "PRICE": 90.3, "STOCK": 2, "BRAND_NAME": "Pantene", "Category": "Apparel | Girls Wear | Vestidos", "ITEM_DESCRIPTION": "Sal Con Ajo En Frasco 140 Grs", "ITEM_IMG": "https://locahost:8000/images/7501010788818?height=500&width=500", "ITEM_NAME": "Sal Con Ajo En Frasco", "Package": "140 GRS", "SKU": 165448}, {"EAN": 780341300136, "BRANCH": "MM", "PRICE": 90.3, "STOCK": 5, "BRAND_NAME": "Rubbermaid", "Category": "Entertainment | Toys & Hobbies | Action Figures & Collectibles", "ITEM_DESCRIPTION": "Coliza Peruana 10Kg", "ITEM_IMG": "https://locahost:8000/images/780341300136?height=500&width=500", "ITEM_NAME": "Pan Coliza", "Package": "10KG", "SKU": 43311}, {"EAN": 650240030529, "BRANCH": "MM", "PRICE": 90.3, "STOCK": 4, "BRAND_NAME": "Happy Hop", "Category": "Hardlines | Disposable And Birthday Party Supplies | Suministro Fiestas", "ITEM_DESCRIPTION": "Shampoo Control Caspa 400 Ml.", "ITEM_IMG": "https://locahost:8000/images/650240030529?height=500&width=500", "ITEM_NAME": "Shampoo Control Caspa", "Package": "400 ML.", "SKU": 210698}, {"EAN": 7506309819815, "BRANCH": "MM", "PRICE": 90.3, "STOCK": 2, "BRAND_NAME": "Laki", "Category": "Home | Home Furnishings | Terraza", "ITEM_DESCRIPTION": "Oferta Armada Maquina De Afeitar Mas 2 Pza", "ITEM_IMG": "https://locahost:8000/images/7506309819815?height=500&width=500", "ITEM_NAME": "Oferta Armada Maquina De Afeitar Mas", "Package": "2 PZA", "SKU": 242652}, {"EAN": 759684154836, "BRANCH": "MM", "PRICE": 90.3, "STOCK": 3, "BRAND_NAME": "Leffe", "Category": "Grocery | 92 Grocery | Diet And Health", "ITEM_DESCRIPTION": "Crema Bevo 115483", "ITEM_IMG": "https://locahost:8000/images/759684154836?height=500&width=500", "ITEM_NAME": "Crema Bevo 115483", "Package": "115483", "SKU": 313635}, {"EAN": 780281003107, "BRANCH": "MM", "PRICE": 90.3, "STOCK": 1, "BRAND_NAME": "Lola", "Category": "Grocery | Frozen Foods | Appetizers - Prepared Frozen", "ITEM_DESCRIPTION": "Mermelada Frutilla 250Gr", "ITEM_IMG": "https://locahost:8000/images/780281003107?height=500&width=500", "ITEM_NAME": "Merm. Regular Bolsa", "Package": "250GR", "SKU": 14525}]'

# %%
final_df
# Out:
#                    EAN BRANCH  PRICE  STOCK     BRAND_NAME  \
# 1        7501035912854   RHSM   15.3      5    Studio Line
# 15       8410030007788   RHSM   64.2      5       Microlab
# 18         33383653006   RHSM   79.5      3        Karcher
# 22         40000658928     MM   23.7      5  Altec Lansing
# 25        780292000652   RHSM   47.1      2            H2O
# ...                ...    ...    ...    ...            ...
# 2296732  5013665113355   RHSM   36.0      3      Sterilite
# 2296742  3700906700338     MM   81.9      2         Canada
# 2296752  7506145820570     MM   49.2      1     Damablanca
# 2296764  7503023492065   RHSM   59.4      3     Baby Shark
# 2296766  7501010776754     MM    4.5      5   Westinghouse
#
#                                                   Category  \
# 1        Deli Meat & Cheese | Service Deli | Com Prepar...
# 15       Hardlines | Disposable And Birthday Party Supp...
# 18                      Bakery | Bakery | Cakes - In Store
# 22        Hardlines | Stationary & Party Goods | Cuadernos
# 25                    Home | Domestic Goods | Toallas Baño
# ...                                                    ...
# 2296732               Hardlines | Books And Gifts | Todo A
# 2296742       Consumables | Health And Beauty Aids | Color
# 2296752  Pets | Pets And Supplies | Mascotas - Cuidado ...
# 2296764  Grocery | 92 Grocery | Dessert-Topping Filling...
# 2296766  Hardlines | Stationary & Party Goods | Crafts ...
#
#                                          ITEM_DESCRIPTION  \
# 1                    Cepillo Dental Infantil Tarzan 0 Pza
# 15                Vino Tinto Maruqes De Penamonte 750 Ml.
# 18                                  Corazon De Apio 1 Pza
# 22                               Calcetin Dep Bgn3739 1Un
# 25                              Q Crema Unt Nat 100 100Gr
# ...                                                   ...
# 2296732  Crema 100% De Cacahuates Organica Crujie 227 Grs
# 2296742                Vino Rosado Divine Justine 750 Ml.
# 2296752          Cobertor Home Line Cmfe1802Sb Matrimonia
# 2296764                Sandalia Simple Fash, 23, Plateado
# 2296766                              Tenedor Jumbo 25 Bol
#
#                                                   ITEM_IMG  \
# 1        https://locahost:8000/images/7501035912854?hei...
# 15       https://locahost:8000/images/8410030007788?hei...
# 18       https://locahost:8000/images/33383653006?heigh...
# 22       https://locahost:8000/images/40000658928?heigh...
# 25       https://locahost:8000/images/780292000652?heig...
# ...                                                    ...
# 2296732  https://locahost:8000/images/5013665113355?hei...
# 2296742  https://locahost:8000/images/3700906700338?hei...
# 2296752  https://locahost:8000/images/7506145820570?hei...
# 2296764  https://locahost:8000/images/7503023492065?hei...
# 2296766  https://locahost:8000/images/7501010776754?hei...
#
#                                         ITEM_NAME            Package     SKU
# 1                  Cepillo Dental Infantil Tarzan              0 PZA  223240
# 15                Vino Tinto Maruqes De Penamonte            750 ML.   85778
# 18                                Corazon De Apio              1 PZA  111612
# 22                             Calcetin Deportivo                1UN   58179
# 25                                Untable/Fundido              100GR   23522
# ...                                           ...                ...     ...
# 2296732  Crema 100% De Cacahuates Organica Crujie            227 GRS  133086
# 2296742                Vino Rosado Divine Justine            750 ML.   87273
# 2296752  Cobertor Home Line Cmfe1802Sb Matrimonia  1802SB MATRIMONIA  306369
# 2296764        Sandalia Simple Fash, 23, Plateado       23, PLATEADO  296517
# 2296766                             Tenedor Jumbo             25 BOL  196940
#
# [460002 rows x 11 columns]

# %%
PRICES_STOCK_CSV = "PRICES-STOCK.csv"
PRODUCTS_CSV = "PRODUCTS.csv"

prices_stock_df = pd.read_csv(PRICES_STOCK_CSV, sep='|'  , engine='python')
products_df = pd.read_csv(PRODUCTS_CSV, sep='|'  , engine='python')

# %%
# Clean text
new_products = products_df['ITEM_DESCRIPTION'].str.replace("[<p>/]","", regex=True)
products_df['ITEM_DESCRIPTION'] = new_products

# Combine category, sub-category, and sub-sub-category into one category 
# separated by a pipe symbol in lower case
products_df['Category'] = products_df['CATEGORY'] + ' | ' + products_df['SUB_CATEGORY'] + ' | ' + products_df['SUB_SUB_CATEGORY']
products_df['Category'] = products_df['Category'].str.title()

# %%
import re

pattern = re.compile(r'(\d+(?!.*\d).*)')

s = products_df['ITEM_DESCRIPTION'].str.extract(pattern, expand=True)

products_df['Package'] = s

# %%
products_df
# Out:
#            SKU BUY_UNIT DESCRIPTION_STATUS ORGANIC_ITEM  KIRLAND_ITEM  \
# 0        52572       UN                  B          NaN         False
# 1       278100      NaN                  R          NaN          True
# 2        27404       KG                  B          NaN          True
# 3       215143       UN                 CD            Y          True
# 4        85805       KG                 CD            N         False
# ...        ...      ...                ...          ...           ...
# 321537   37542       UN                NaN            N         False
# 321538  199851      NaN                  R            Y          True
# 321539  144269      NaN                  R            Y          True
# 321540  312844       KG                  B          NaN          True
# 321541   60891       UN                NaN          NaN          True
#
#         FINELINE_NUMBER            EAN                            ITEM_NAME  \
# 0                713115   693177767936                             CANASTOS
# 1                345827            399                   LIMÓN COLIMA KG
# 2                134923   762230099043                              CHICLES
# 3                773663  7501199416236  JABON LIQUIDO PARA MANOS VITAMINA E
# 4                233313  8410113003119   VINO TINTO GRAN CORONAS TORRES 750
# ...                 ...            ...                                  ...
# 321537           966232   698400300544                      LOZA BASICA GRA
# 321538           855034  7501199404301             DETERGENTE LIQUIDO COLOR
# 321539           434058  7501006555752      2 SOBRES PALOMITAS  + VALENTINA
# 321540           305744  6971165068775     CAMISA JORDACHE J, BLANCO, EG/XL
# 321541           975067    40000695373                                 SOFA
#
#                                    ITEM_DESCRIPTION  \
# 0                           CANASTO CONEJO F1 A 1UN
# 1                                LIMÓN COLIMA KG
# 2                             TRIDENT 6S SANDIA 9GR
# 3       JABON LIQUIDO PARA MANOS VITAMINA E 442 ML.
# 4          VINO TINTO GRAN CORONAS TORRES 750 1 PZA
# ...                                             ...
# 321537                       TAZA CONSOME 280CC 1UN
# 321538                DETERGENTE LIQUIDO COLOR 5 LT
# 321539        2 SOBRES PALOMITAS  + VALENTINA 1 PZA
# 321540              CAMISA JORDACHE J, BLANCO, EGXL
# 321541                      SOFA SOC T-PU CHOCO 1UN
#
#                                                  ITEM_IMG       CATEGORY  \
# 0       https://locahost:8000/images/693177767936?heig...        APPAREL
# 1       https://locahost:8000/images/399?height=500&wi...  ENTERTAINMENT
# 2       https://locahost:8000/images/762230099043?heig...      HARDLINES
# 3       https://locahost:8000/images/7501199416236?hei...      HARDLINES
# 4       https://locahost:8000/images/8410113003119?hei...    CONSUMABLES
# ...                                                   ...            ...
# 321537  https://locahost:8000/images/698400300544?heig...      HARDLINES
# 321538  https://locahost:8000/images/7501199404301?hei...        GROCERY
# 321539  https://locahost:8000/images/7501006555752?hei...  ENTERTAINMENT
# 321540  https://locahost:8000/images/6971165068775?hei...        GROCERY
# 321541  https://locahost:8000/images/40000695373?heigh...    MEAT & FISH
#
#                SUB_CATEGORY              SUB_SUB_CATEGORY       BRAND_NAME  \
# 0                 MENS WEAR                MEN - T-SHIRTS   PUPPY DOG PALS
# 1            TOYS & HOBBIES                      PELUCHES         ENTRECOT
# 2                AUTOMOTIVE          APARIENCIA AUTOMOVIL            SPURA
# 3                  SEASONAL             SEASONAL - EASTER          CHAMYTO
# 4       HOUSEHOLD CHEMICALS      AIR FRESHENER-DEODORIZER          POOPSIE
# ...                     ...                           ...              ...
# 321537             HARDWARE                   VENTILACION  HO DON CUSTODIO
# 321538       DAIRY PRODUCTS            BUTTER-SUBSTITUTES          MADEMSA
# 321539          ELECTRONICS              EQUIPOS DE AUDIO         DON JUAN
# 321540           92 GROCERY  MILK-CREAM-SUBSTITUTES-SHELF            MEYER
# 321541              SEAFOOD                SEAFOOD - FISH           TAIWAN
#
#                                                  Category  Package
# 0                    Apparel | Mens Wear | Men - T-Shirts      1UN
# 1               Entertainment | Toys & Hobbies | Peluches      NaN
# 2           Hardlines | Automotive | Apariencia Automovil      9GR
# 3                Hardlines | Seasonal | Seasonal - Easter  442 ML.
# 4       Consumables | Household Chemicals | Air Freshe...    1 PZA
# ...                                                   ...      ...
# 321537                 Hardlines | Hardware | Ventilacion      1UN
# 321538      Grocery | Dairy Products | Butter-Substitutes     5 LT
# 321539     Entertainment | Electronics | Equipos De Audio    1 PZA
# 321540  Grocery | 92 Grocery | Milk-Cream-Substitutes-...      NaN
# 321541             Meat & Fish | Seafood | Seafood - Fish      1UN
#
# [321542 rows x 16 columns]

# %%
products_df['ITEM_NAME'] = products_df['ITEM_NAME'].str.title()
products_df['ITEM_DESCRIPTION'] = products_df['ITEM_DESCRIPTION'].str.title()
products_df['BRAND_NAME'] = products_df['BRAND_NAME'].str.title()
products_df
# Out:
#            SKU BUY_UNIT DESCRIPTION_STATUS ORGANIC_ITEM  KIRLAND_ITEM  \
# 0        52572       UN                  B          NaN         False
# 1       278100      NaN                  R          NaN          True
# 2        27404       KG                  B          NaN          True
# 3       215143       UN                 CD            Y          True
# 4        85805       KG                 CD            N         False
# ...        ...      ...                ...          ...           ...
# 321537   37542       UN                NaN            N         False
# 321538  199851      NaN                  R            Y          True
# 321539  144269      NaN                  R            Y          True
# 321540  312844       KG                  B          NaN          True
# 321541   60891       UN                NaN          NaN          True
#
#         FINELINE_NUMBER            EAN                            ITEM_NAME  \
# 0                713115   693177767936                             Canastos
# 1                345827            399                   Limón Colima Kg
# 2                134923   762230099043                              Chicles
# 3                773663  7501199416236  Jabon Liquido Para Manos Vitamina E
# 4                233313  8410113003119   Vino Tinto Gran Coronas Torres 750
# ...                 ...            ...                                  ...
# 321537           966232   698400300544                      Loza Basica Gra
# 321538           855034  7501199404301             Detergente Liquido Color
# 321539           434058  7501006555752      2 Sobres Palomitas  + Valentina
# 321540           305744  6971165068775     Camisa Jordache J, Blanco, Eg/Xl
# 321541           975067    40000695373                                 Sofa
#
#                                    ITEM_DESCRIPTION  \
# 0                           Canasto Conejo F1 A 1Un
# 1                                Limón Colima Kg
# 2                             Trident 6S Sandia 9Gr
# 3       Jabon Liquido Para Manos Vitamina E 442 Ml.
# 4          Vino Tinto Gran Coronas Torres 750 1 Pza
# ...                                             ...
# 321537                       Taza Consome 280Cc 1Un
# 321538                Detergente Liquido Color 5 Lt
# 321539        2 Sobres Palomitas  + Valentina 1 Pza
# 321540              Camisa Jordache J, Blanco, Egxl
# 321541                      Sofa Soc T-Pu Choco 1Un
#
#                                                  ITEM_IMG       CATEGORY  \
# 0       https://locahost:8000/images/693177767936?heig...        APPAREL
# 1       https://locahost:8000/images/399?height=500&wi...  ENTERTAINMENT
# 2       https://locahost:8000/images/762230099043?heig...      HARDLINES
# 3       https://locahost:8000/images/7501199416236?hei...      HARDLINES
# 4       https://locahost:8000/images/8410113003119?hei...    CONSUMABLES
# ...                                                   ...            ...
# 321537  https://locahost:8000/images/698400300544?heig...      HARDLINES
# 321538  https://locahost:8000/images/7501199404301?hei...        GROCERY
# 321539  https://locahost:8000/images/7501006555752?hei...  ENTERTAINMENT
# 321540  https://locahost:8000/images/6971165068775?hei...        GROCERY
# 321541  https://locahost:8000/images/40000695373?heigh...    MEAT & FISH
#
#                SUB_CATEGORY              SUB_SUB_CATEGORY       BRAND_NAME  \
# 0                 MENS WEAR                MEN - T-SHIRTS   Puppy Dog Pals
# 1            TOYS & HOBBIES                      PELUCHES         Entrecot
# 2                AUTOMOTIVE          APARIENCIA AUTOMOVIL            Spura
# 3                  SEASONAL             SEASONAL - EASTER          Chamyto
# 4       HOUSEHOLD CHEMICALS      AIR FRESHENER-DEODORIZER          Poopsie
# ...                     ...                           ...              ...
# 321537             HARDWARE                   VENTILACION  Ho Don Custodio
# 321538       DAIRY PRODUCTS            BUTTER-SUBSTITUTES          Mademsa
# 321539          ELECTRONICS              EQUIPOS DE AUDIO         Don Juan
# 321540           92 GROCERY  MILK-CREAM-SUBSTITUTES-SHELF            Meyer
# 321541              SEAFOOD                SEAFOOD - FISH           Taiwan
#
#                                                  Category  Package
# 0                    Apparel | Mens Wear | Men - T-Shirts      1UN
# 1               Entertainment | Toys & Hobbies | Peluches      NaN
# 2           Hardlines | Automotive | Apariencia Automovil      9GR
# 3                Hardlines | Seasonal | Seasonal - Easter  442 ML.
# 4       Consumables | Household Chemicals | Air Freshe...    1 PZA
# ...                                                   ...      ...
# 321537                 Hardlines | Hardware | Ventilacion      1UN
# 321538      Grocery | Dairy Products | Butter-Substitutes     5 LT
# 321539     Entertainment | Electronics | Equipos De Audio    1 PZA
# 321540  Grocery | 92 Grocery | Milk-Cream-Substitutes-...      NaN
# 321541             Meat & Fish | Seafood | Seafood - Fish      1UN
#
# [321542 rows x 16 columns]

# %%
df_merge = pd.merge(products_df, prices_stock_df, how='right')
df_merge
# Out:
#             SKU BUY_UNIT DESCRIPTION_STATUS ORGANIC_ITEM  KIRLAND_ITEM  \
# 0        142308      NaN                  A          NaN         False
# 1        223240       UN                  B          NaN         False
# 2         49514       KG                 CD          NaN          True
# 3        111807       KG                  R          NaN         False
# 4        223543      NaN                 CD          NaN         False
# ...         ...      ...                ...          ...           ...
# 2296762  243017       UN                NaN            Y          True
# 2296763  185713       UN                 CD            N         False
# 2296764  296517       UN                  A            N          True
# 2296765   52814      NaN                  B            N          True
# 2296766  196940      NaN                NaN            N         False
#
#          FINELINE_NUMBER            EAN                             ITEM_NAME  \
# 0                 598980  5060108450089                    Agua Tonica Ginger
# 1                 786651  7501035912854        Cepillo Dental Infantil Tarzan
# 2                 607009   775512804491                        Juegos De Mesa
# 3                 420531   898685001166                                  Jugo
# 4                 379448  7509552913170          Crema Facial 3 En1 Aclarante
# ...                  ...            ...                                   ...
# 2296762            94622    75486087999      Bronceador Fps 30 Zanahoria Sray
# 2296763           546547   735257001493  Gelatina De Agua Sabor Cereza 140 Gr
# 2296764           892065  7503023492065    Sandalia Simple Fash, 23, Plateado
# 2296765           335651   780220012903                                 Malva
# 2296766           310412  7501010776754                         Tenedor Jumbo
#
#                                      ITEM_DESCRIPTION  \
# 0                          Agua Tonica Ginger 200 Ml.
# 1                Cepillo Dental Infantil Tarzan 0 Pza
# 2                                 Puzzle 9 Piezas 1Un
# 3                                        Jugo 946 Ml.
# 4                Crema Facial 3 En1 Aclarante 200 Ml.
# ...                                               ...
# 2296762      Bronceador Fps 30 Zanahoria Sray 180 Ml.
# 2296763  Gelatina De Agua Sabor Cereza 140 Gr 140 Grs
# 2296764            Sandalia Simple Fash, 23, Plateado
# 2296765                      Marshmallow Trenza 250Gr
# 2296766                          Tenedor Jumbo 25 Bol
#
#                                                   ITEM_IMG  \
# 0        https://locahost:8000/images/5060108450089?hei...
# 1        https://locahost:8000/images/7501035912854?hei...
# 2        https://locahost:8000/images/775512804491?heig...
# 3        https://locahost:8000/images/898685001166?heig...
# 4        https://locahost:8000/images/7509552913170?hei...
# ...                                                    ...
# 2296762  https://locahost:8000/images/75486087999?heigh...
# 2296763  https://locahost:8000/images/735257001493?heig...
# 2296764  https://locahost:8000/images/7503023492065?hei...
# 2296765  https://locahost:8000/images/780220012903?heig...
# 2296766  https://locahost:8000/images/7501010776754?hei...
#
#                    CATEGORY              SUB_CATEGORY  \
# 0        DELI MEAT & CHEESE                LUNCH MEAT
# 1        DELI MEAT & CHEESE              SERVICE DELI
# 2                   APPAREL               LADIES WEAR
# 3                 HARDLINES     PAINT AND ACCESSORIES
# 4                   GROCERY                92 GROCERY
# ...                     ...                       ...
# 2296762                HOME           FABRIC & CRAFTS
# 2296763       ENTERTAINMENT     ELECTRICAL APPLIANCES
# 2296764             GROCERY                92 GROCERY
# 2296765              BAKERY          COMMERCIAL BREAD
# 2296766           HARDLINES  STATIONARY & PARTY GOODS
#
#                      SUB_SUB_CATEGORY        BRAND_NAME  \
# 0                               DULCE     Betty Crocker
# 1                      COM PREPARADAS       Studio Line
# 2               LADY - JUVENIL CASUAL             Jovan
# 3                  PINTURA - EXTERIOR  Underskin By Top
# 4                    SUGAR-SUBSTITUTE       Ocean Spray
# ...                               ...               ...
# 2296762           FLORAL - ACCESORIOS      Dermovagisil
# 2296763                   CALEFACCION            Natura
# 2296764  DESSERT-TOPPING FILLING BASE        Baby Shark
# 2296765            BREAD SHELF STABLE  Princesita Sofia
# 2296766        CRAFTS - CHILDRENS ART      Westinghouse
#
#                                                   Category       Package  \
# 0                  Deli Meat & Cheese | Lunch Meat | Dulce       200 ML.
# 1        Deli Meat & Cheese | Service Deli | Com Prepar...         0 PZA
# 2            Apparel | Ladies Wear | Lady - Juvenil Casual           1UN
# 3        Hardlines | Paint And Accessories | Pintura - ...       946 ML.
# 4                  Grocery | 92 Grocery | Sugar-Substitute       200 ML.
# ...                                                    ...           ...
# 2296762       Home | Fabric & Crafts | Floral - Accesorios       180 ML.
# 2296763  Entertainment | Electrical Appliances | Calefa...       140 GRS
# 2296764  Grocery | 92 Grocery | Dessert-Topping Filling...  23, PLATEADO
# 2296765     Bakery | Commercial Bread | Bread Shelf Stable         250GR
# 2296766  Hardlines | Stationary & Party Goods | Crafts ...        25 BOL
#
#         BRANCH  PRICE  STOCK
# 0          HRO   45.6      3
# 1         RHSM   15.3      5
# 2         RHSM   56.7     -2
# 3         RHSM   48.0     -4
# 4           MS    8.7     -1
# ...        ...    ...    ...
# 2296762    HRO   73.2      4
# 2296763     MS   85.5      2
# 2296764   RHSM   59.4      3
# 2296765     MS   23.7     -1
# 2296766     MM    4.5      5
#
# [2296767 rows x 19 columns]

# %%
# Select only MM and RHSM branches that have stock
filt = ((df_merge['BRANCH'] == 'MM') | (df_merge['BRANCH'] == 'RHSM')) & (df_merge['STOCK'] > 0)
filt_branch_stock = df_merge.loc[filt]
filt_branch_stock
# Out:
#             SKU BUY_UNIT DESCRIPTION_STATUS ORGANIC_ITEM  KIRLAND_ITEM  \
# 1        223240       UN                  B          NaN         False
# 15        85778      NaN                 CD            Y          True
# 18       111612       KG                  R            Y         False
# 22        58179       UN                  A            N          True
# 25        23522       KG                  R            N          True
# ...         ...      ...                ...          ...           ...
# 2296732  133086      NaN                 CD            Y         False
# 2296742   87273      NaN                  B            Y          True
# 2296752  306369       KG                 CD            N          True
# 2296764  296517       UN                  A            N          True
# 2296766  196940      NaN                NaN            N         False
#
#          FINELINE_NUMBER            EAN  \
# 1                 786651  7501035912854
# 15                859191  8410030007788
# 18                377418    33383653006
# 22                103112    40000658928
# 25                652595   780292000652
# ...                  ...            ...
# 2296732           608556  5013665113355
# 2296742           511829  3700906700338
# 2296752           555864  7506145820570
# 2296764           892065  7503023492065
# 2296766           310412  7501010776754
#
#                                         ITEM_NAME  \
# 1                  Cepillo Dental Infantil Tarzan
# 15                Vino Tinto Maruqes De Penamonte
# 18                                Corazon De Apio
# 22                             Calcetin Deportivo
# 25                                Untable/Fundido
# ...                                           ...
# 2296732  Crema 100% De Cacahuates Organica Crujie
# 2296742                Vino Rosado Divine Justine
# 2296752  Cobertor Home Line Cmfe1802Sb Matrimonia
# 2296764        Sandalia Simple Fash, 23, Plateado
# 2296766                             Tenedor Jumbo
#
#                                          ITEM_DESCRIPTION  \
# 1                    Cepillo Dental Infantil Tarzan 0 Pza
# 15                Vino Tinto Maruqes De Penamonte 750 Ml.
# 18                                  Corazon De Apio 1 Pza
# 22                               Calcetin Dep Bgn3739 1Un
# 25                              Q Crema Unt Nat 100 100Gr
# ...                                                   ...
# 2296732  Crema 100% De Cacahuates Organica Crujie 227 Grs
# 2296742                Vino Rosado Divine Justine 750 Ml.
# 2296752          Cobertor Home Line Cmfe1802Sb Matrimonia
# 2296764                Sandalia Simple Fash, 23, Plateado
# 2296766                              Tenedor Jumbo 25 Bol
#
#                                                   ITEM_IMG  \
# 1        https://locahost:8000/images/7501035912854?hei...
# 15       https://locahost:8000/images/8410030007788?hei...
# 18       https://locahost:8000/images/33383653006?heigh...
# 22       https://locahost:8000/images/40000658928?heigh...
# 25       https://locahost:8000/images/780292000652?heig...
# ...                                                    ...
# 2296732  https://locahost:8000/images/5013665113355?hei...
# 2296742  https://locahost:8000/images/3700906700338?hei...
# 2296752  https://locahost:8000/images/7506145820570?hei...
# 2296764  https://locahost:8000/images/7503023492065?hei...
# 2296766  https://locahost:8000/images/7501010776754?hei...
#
#                    CATEGORY                            SUB_CATEGORY  \
# 1        DELI MEAT & CHEESE                            SERVICE DELI
# 15                HARDLINES  DISPOSABLE AND BIRTHDAY PARTY SUPPLIES
# 18                   BAKERY                                  BAKERY
# 22                HARDLINES                STATIONARY & PARTY GOODS
# 25                     HOME                          DOMESTIC GOODS
# ...                     ...                                     ...
# 2296732           HARDLINES                         BOOKS AND GIFTS
# 2296742         CONSUMABLES                  HEALTH AND BEAUTY AIDS
# 2296752                PETS                       PETS AND SUPPLIES
# 2296764             GROCERY                              92 GROCERY
# 2296766           HARDLINES                STATIONARY & PARTY GOODS
#
#                      SUB_SUB_CATEGORY     BRAND_NAME  \
# 1                      COM PREPARADAS    Studio Line
# 15                 SUMINISTRO FIESTAS       Microlab
# 18                   CAKES - IN STORE        Karcher
# 22                          CUADERNOS  Altec Lansing
# 25                       TOALLAS BAÑO            H2O
# ...                               ...            ...
# 2296732                        TODO A      Sterilite
# 2296742                         COLOR         Canada
# 2296752  MASCOTAS - CUIDADO - HIGIENE     Damablanca
# 2296764  DESSERT-TOPPING FILLING BASE     Baby Shark
# 2296766        CRAFTS - CHILDRENS ART   Westinghouse
#
#                                                   Category            Package  \
# 1        Deli Meat & Cheese | Service Deli | Com Prepar...              0 PZA
# 15       Hardlines | Disposable And Birthday Party Supp...            750 ML.
# 18                      Bakery | Bakery | Cakes - In Store              1 PZA
# 22        Hardlines | Stationary & Party Goods | Cuadernos                1UN
# 25                    Home | Domestic Goods | Toallas Baño              100GR
# ...                                                    ...                ...
# 2296732               Hardlines | Books And Gifts | Todo A            227 GRS
# 2296742       Consumables | Health And Beauty Aids | Color            750 ML.
# 2296752  Pets | Pets And Supplies | Mascotas - Cuidado ...  1802SB MATRIMONIA
# 2296764  Grocery | 92 Grocery | Dessert-Topping Filling...       23, PLATEADO
# 2296766  Hardlines | Stationary & Party Goods | Crafts ...             25 BOL
#
#         BRANCH  PRICE  STOCK
# 1         RHSM   15.3      5
# 15        RHSM   64.2      5
# 18        RHSM   79.5      3
# 22          MM   23.7      5
# 25        RHSM   47.1      2
# ...        ...    ...    ...
# 2296732   RHSM   36.0      3
# 2296742     MM   81.9      2
# 2296752     MM   49.2      1
# 2296764   RHSM   59.4      3
# 2296766     MM    4.5      5
#
# [460002 rows x 19 columns]

# %%
final_df = filt_branch_stock[['EAN', 'BRANCH', 'PRICE', 'STOCK', 'BRAND_NAME', 'Category', 'ITEM_DESCRIPTION', 'ITEM_IMG', 'ITEM_NAME', 'Package', 'SKU']]
final_df
# Out:
#                    EAN BRANCH  PRICE  STOCK     BRAND_NAME  \
# 1        7501035912854   RHSM   15.3      5    Studio Line
# 15       8410030007788   RHSM   64.2      5       Microlab
# 18         33383653006   RHSM   79.5      3        Karcher
# 22         40000658928     MM   23.7      5  Altec Lansing
# 25        780292000652   RHSM   47.1      2            H2O
# ...                ...    ...    ...    ...            ...
# 2296732  5013665113355   RHSM   36.0      3      Sterilite
# 2296742  3700906700338     MM   81.9      2         Canada
# 2296752  7506145820570     MM   49.2      1     Damablanca
# 2296764  7503023492065   RHSM   59.4      3     Baby Shark
# 2296766  7501010776754     MM    4.5      5   Westinghouse
#
#                                                   Category  \
# 1        Deli Meat & Cheese | Service Deli | Com Prepar...
# 15       Hardlines | Disposable And Birthday Party Supp...
# 18                      Bakery | Bakery | Cakes - In Store
# 22        Hardlines | Stationary & Party Goods | Cuadernos
# 25                    Home | Domestic Goods | Toallas Baño
# ...                                                    ...
# 2296732               Hardlines | Books And Gifts | Todo A
# 2296742       Consumables | Health And Beauty Aids | Color
# 2296752  Pets | Pets And Supplies | Mascotas - Cuidado ...
# 2296764  Grocery | 92 Grocery | Dessert-Topping Filling...
# 2296766  Hardlines | Stationary & Party Goods | Crafts ...
#
#                                          ITEM_DESCRIPTION  \
# 1                    Cepillo Dental Infantil Tarzan 0 Pza
# 15                Vino Tinto Maruqes De Penamonte 750 Ml.
# 18                                  Corazon De Apio 1 Pza
# 22                               Calcetin Dep Bgn3739 1Un
# 25                              Q Crema Unt Nat 100 100Gr
# ...                                                   ...
# 2296732  Crema 100% De Cacahuates Organica Crujie 227 Grs
# 2296742                Vino Rosado Divine Justine 750 Ml.
# 2296752          Cobertor Home Line Cmfe1802Sb Matrimonia
# 2296764                Sandalia Simple Fash, 23, Plateado
# 2296766                              Tenedor Jumbo 25 Bol
#
#                                                   ITEM_IMG  \
# 1        https://locahost:8000/images/7501035912854?hei...
# 15       https://locahost:8000/images/8410030007788?hei...
# 18       https://locahost:8000/images/33383653006?heigh...
# 22       https://locahost:8000/images/40000658928?heigh...
# 25       https://locahost:8000/images/780292000652?heig...
# ...                                                    ...
# 2296732  https://locahost:8000/images/5013665113355?hei...
# 2296742  https://locahost:8000/images/3700906700338?hei...
# 2296752  https://locahost:8000/images/7506145820570?hei...
# 2296764  https://locahost:8000/images/7503023492065?hei...
# 2296766  https://locahost:8000/images/7501010776754?hei...
#
#                                         ITEM_NAME            Package     SKU
# 1                  Cepillo Dental Infantil Tarzan              0 PZA  223240
# 15                Vino Tinto Maruqes De Penamonte            750 ML.   85778
# 18                                Corazon De Apio              1 PZA  111612
# 22                             Calcetin Deportivo                1UN   58179
# 25                                Untable/Fundido              100GR   23522
# ...                                           ...                ...     ...
# 2296732  Crema 100% De Cacahuates Organica Crujie            227 GRS  133086
# 2296742                Vino Rosado Divine Justine            750 ML.   87273
# 2296752  Cobertor Home Line Cmfe1802Sb Matrimonia  1802SB MATRIMONIA  306369
# 2296764        Sandalia Simple Fash, 23, Plateado       23, PLATEADO  296517
# 2296766                             Tenedor Jumbo             25 BOL  196940
#
# [460002 rows x 11 columns]
